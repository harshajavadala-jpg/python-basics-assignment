# %% [markdown]
# <a href="https://colab.research.google.com/github/harshajavadala-jpg/python-basics-assignment/blob/main/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hardware is the physical components of a computer that you can touch, while software is the programs and instructions that run on the hardware.
#
# Example of Hardware: A laptop's CPU (processor), RAM (memory), or hard drive
#
# Example of Software: Microsoft Word, Google Chrome, or the Windows operating system
